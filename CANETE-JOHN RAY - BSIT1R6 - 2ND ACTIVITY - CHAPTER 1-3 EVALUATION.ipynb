# %%
print("Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters")


print("On chapter 1 learned a lot about algorithms and Data Structure. I able to know what is the purpose of data structure and")
print("algorithm. In the video I able to know the characteristics of an algorithm and Data Structure. As well as why those ")
print("characteristics. As well as why those characteristics is important in data structures and algorithm. So first let's go ")
print("with algorithm. Algorithm is all about sequence of computational steps that transform the input to output.")
print("The first characteristics of algorithm is unambiguous. Of course we need to make our algorithm clear as possible and it ")
print("only lead to one meaning. The next characteristics is that it should have an input as well as output. The next one is ")
print("Finiteness. Finiteness for the reason that we dont want to have infinite steps in our algorithm. Next is that Feasibility")
print("and the last one is the independent to any programming language. The next is the Data Structure. In Data structure we ")
print("store and organize data. Of course no one want to have a data that is not organized well. It has 2 foundation of data ")
print("structure. Interface and implementation. Interface represent as the operation that a data structure supports. On the ")
print("other hand implentation, it provides the internal representation of a data structure and also the definition of algorithm")
print("used in the operations of the data structure. Data structure have 3 important characteristics. Correctness, time")
print("complexity, and space complexity. We need to learn Data structure and algorithm because of these 3. Data search, imagine")
print("if you have billions or millions of data that store. If you want to search for something and it will search billions of  ")
print("data of course it is time consuming and slow. As the data grows it will become slower. The next one is processor speed. ")
print("and the last one is the multiple request, if the user are searching simultaneously it the server will fail.")
# Out:
# On chapter 1 learned a lot about algorithms and Data Structure. I able to know what is the purpose of data structure and
# algorithm. In the video I able to know the characteristics of an algorithm and Data Structure. As well as why those
# characteristics. As well as why those characteristics is important in data structures and algorithm. So first let's go
# with algorithm. Algorithm is all about sequence of computational steps that transform the input to output.
# The first characteristics of algorithm is unambiguous. Of course we need to make our algorithm clear as possible and it
# only lead to one meaning. The next characteristics is that it should have an input as well as output. The next one is
# Finiteness. Finiteness for the reason that we dont want to have infinite steps in our algorithm. Next is that Feasibility
# and the last one is the independent to any programming language. The next is the Data Structure. In Data structure we
# ...

# %%
print("Discuss your learnings on Chapter 1  time-frame 35:00 - end. Minimum of 200 characters")


print("Algorithm can be analyzed in two stages before implementation and after implementation. The first is what we call a priori")
print("Analysis. It is the theoretical analysis of an algorithm. We are assuming that the data structure that you are making wont")
print("affect the processor speed. The next  is the posterior analysis. This analysis is an empirical analysis of algorithm. ")
print("In this analysis you are executing with the use of programming langauge like C++, python, java, C and etc.  ")
print("There are two types of Algorithm Complexity. The time factor and space factor. This two is very important. In tspace ")
print("Complexity there are two components. The fixed part and variable part. Example of fixed part are simple variable and ")
print("constant used. Example of variable part are dynamic memory allocation recursion stack space and etc. ")
# Out:
# Algorithm can be analyzed in two stages before implementation and after implementation. The first is what we call a priori
# Analysis. It is the theoretical analysis of an algorithm. We are assuming that the data structure that you are making wont
# affect the processor speed. The next  is the posterior analysis. This analysis is an empirical analysis of algorithm.
# In this analysis you are executing with the use of programming langauge like C++, python, java, C and etc.
# There are two types of Algorithm Complexity. The time factor and space factor. This two is very important. In tspace
# Complexity there are two components. The fixed part and variable part. Example of fixed part are simple variable and
# constant used. Example of variable part are dynamic memory allocation recursion stack space and etc.

# %%
print("Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters")


print("Every language has a built-in data types. These are the provide built-in data type integers (it is a whole number), ")
print("boolean(answer by true or false), floating (Decimal nuumbers), and the last one is string and characters. The next is")
print("Derived data type. These data type are combination of built-in data types and associated operation on them. Example of ")
print("Derived data type are list, array, stack, and Queue. The data in data structure are processed by operations. These are")
print("the basic operation Tranversing, Merging, Searching, Insertion, Deletion, and Sorting. ")
# Out:
# Every language has a built-in data types. These are the provide built-in data type integers (it is a whole number),
# boolean(answer by true or false), floating (Decimal nuumbers), and the last one is string and characters. The next is
# Derived data type. These data type are combination of built-in data types and associated operation on them. Example of
# Derived data type are list, array, stack, and Queue. The data in data structure are processed by operations. These are
# the basic operation Tranversing, Merging, Searching, Insertion, Deletion, and Sorting.

# %%
print("Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters")


print("Array can be declared in various way in different language. Index always start at 0. The purpose of index is for us to  ")
print("accessed element. If you have 10 in the '[]' it means you can store 10 elements on it. So before you make an array you ")
print("need to import it's array module first. Array module imported by typing from array import *. Typecodes are codes that are")
print("used to define the type of value that the array will hold. Example of it is i represent as signed intergers, I represent  ")
print("as unsigned intergers and many more. The way you can access the array is to call the name and its index number. If you ")
print("want to insert. First is you need to put the name of the array and then put insert and next is specify index number that")
print("that you want to insert. If you want to remove, same as the insert just replace the insert by remove method. ")
# Out:
# Array can be declared in various way in different language. Index always start at 0. The purpose of index is for us to
# accessed element. If you have 10 in the '[]' it means you can store 10 elements on it. So before you make an array you
# need to import it's array module first. Array module imported by typing from array import *. Typecodes are codes that are
# used to define the type of value that the array will hold. Example of it is i represent as signed intergers, I represent
# as unsigned intergers and many more. The way you can access the array is to call the name and its index number. If you
# want to insert. First is you need to put the name of the array and then put insert and next is specify index number that

# %%
from array import *

# %%
anyArray = array('i', [4,5,6,7,9,8,6,4,7,8])
anyArray.insert(1, 45)
anyArray.remove(6)
anyArray[5] = 10000
for x in anyArray:
    print(x)
# Out:
# 4
# 45
# 5
# 7
# 9
# 10000
# 6
# 4
# 7
# 8
